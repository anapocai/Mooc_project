# %%
import pandas as pd

# %%
url = "https://catalog.ourworldindata.org/garden/covid/latest/compact/compact.csv"
df = pd.read_csv(url)

# %%
print(df['country'].unique())
print(len(df['country'].unique()))
# Out:
# ['Afghanistan' 'Africa' 'Albania' 'Algeria' 'American Samoa' 'Andorra'
#  'Angola' 'Anguilla' 'Antigua and Barbuda' 'Argentina' 'Armenia' 'Aruba'
#  'Asia' 'Asia excl. China' 'Australia' 'Austria' 'Azerbaijan' 'Bahamas'
#  'Bahrain' 'Bangladesh' 'Barbados' 'Belarus' 'Belgium' 'Belize' 'Benin'
#  'Bermuda' 'Bhutan' 'Bolivia' 'Bonaire Sint Eustatius and Saba'
#  'Bosnia and Herzegovina' 'Botswana' 'Brazil' 'British Virgin Islands'
#  'Brunei' 'Bulgaria' 'Burkina Faso' 'Burundi' 'Cambodia' 'Cameroon'
#  'Canada' 'Cape Verde' 'Cayman Islands' 'Central African Republic' 'Chad'
#  'Chile' 'China' 'Colombia' 'Comoros' 'Congo' 'Cook Islands' 'Costa Rica'
#  "Cote d'Ivoire" 'Croatia' 'Cuba' 'Curacao' 'Cyprus' 'Czechia'
#  'Democratic Republic of Congo' 'Denmark' 'Djibouti' 'Dominica'
#  'Dominican Republic' 'East Timor' 'Ecuador' 'Egypt' 'El Salvador'
#  'England' 'England & Wales' 'Equatorial Guinea' 'Eritrea' 'Estonia'
# ...

# %%
print(df.head())
# Out:
#        country        date  total_cases  new_cases  new_cases_smoothed  \
# 0  Afghanistan  2020-01-01          NaN        NaN                 NaN
# 1  Afghanistan  2020-01-02          NaN        NaN                 NaN
# 2  Afghanistan  2020-01-03          NaN        NaN                 NaN
# 3  Afghanistan  2020-01-04          0.0        0.0                 NaN
# 4  Afghanistan  2020-01-05          0.0        0.0                 NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      0.0                    0.0
# 4                      0.0                    0.0
#
#    new_cases_smoothed_per_million  total_deaths  new_deaths  ...  population  \
# 0                             NaN           NaN         NaN  ...  40578801.0
# 1                             NaN           NaN         NaN  ...  40578801.0
# ...

# %%
# Lista dos países
countries = ['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa', 'Andorra', 'Angola', 'Anguilla', 
             'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba', 'Asia', 'Asia excl. China', 'Australia', 
             'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 
             'Belize', 'Benin', 'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba', 
             'Bosnia and Herzegovina', 'Botswana', 'Brazil', 'British Virgin Islands', 'Brunei', 'Bulgaria', 
             'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde', 'Cayman Islands', 
             'Central African Republic', 'Chad', 'Chile', 'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands', 
             'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao', 'Cyprus', 'Czechia', 'Democratic Republic of Congo', 
             'Denmark', 'Djibouti', 'Dominica', 'Dominican Republic', 'East Timor', 'Ecuador', 'Egypt', 'El Salvador', 
             'England', 'England & Wales', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Eswatini', 'Ethiopia', 'Europe', 
             'European Union (27)', 'Falkland Islands', 'Faroe Islands', 'Fiji', 'Finland', 'France', 'French Guiana', 
             'French Polynesia', 'Gabon', 'Gambia', 'Georgia', 'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 
             'Grenada', 'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 
             'High-income countries', 'Honduras', 'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq', 
             'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica', 'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 
             'Kiribati', 'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon', 'Lesotho', 'Liberia', 'Libya', 
             'Liechtenstein', 'Lithuania', 'Low-income countries', 'Lower-middle-income countries', 'Luxembourg', 'Macao', 
             'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta', 'Marshall Islands', 'Martinique', 'Mauritania', 
             'Mauritius', 'Mayotte', 'Mexico', 'Micronesia (country)', 'Moldova', 'Monaco', 'Mongolia', 'Montenegro', 
             'Montserrat', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands', 'New Caledonia', 
             'New Zealand', 'Nicaragua', 'Niger', 'Nigeria', 'Niue', 'North America', 'North Korea', 'North Macedonia', 
             'Northern Ireland', 'Northern Mariana Islands', 'Norway', 'Oceania', 'Oman', 'Pakistan', 'Palau', 'Palestine', 
             'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines', 'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 
             'Qatar', 'Reunion', 'Romania', 'Russia', 'Rwanda', 'Saint Barthelemy', 'Saint Helena', 'Saint Kitts and Nevis', 
             'Saint Lucia', 'Saint Martin (French part)', 'Saint Pierre and Miquelon', 'Saint Vincent and the Grenadines', 
             'Samoa', 'San Marino', 'Sao Tome and Principe', 'Saudi Arabia', 'Scotland', 'Senegal', 'Serbia', 'Seychelles', 
             'Sierra Leone', 'Singapore', 'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia', 'Solomon Islands', 'Somalia', 
             'South Africa', 'South America', 'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan', 'Summer Olympics 2020', 
             'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan', 'Tajikistan', 'Tanzania', 'Thailand', 'Togo', 'Tokelau', 
             'Tonga', 'Transnistria', 'Trinidad and Tobago', 'Tunisia', 'Turkey', 'Turkmenistan', 'Turks and Caicos Islands', 
             'Tuvalu', 'Uganda', 'Ukraine', 'United Arab Emirates', 'United Kingdom', 'United States', 'United States Virgin Islands', 
             'Upper-middle-income countries', 'Uruguay', 'Uzbekistan', 'Vanuatu', 'Vatican', 'Venezuela', 'Vietnam', 'Wales', 
             'Wallis and Futuna', 'Western Sahara', 'Winter Olympics 2022', 'World', 'World excl. China', 'World excl. China and South Korea', 
             'World excl. China, South Korea, Japan and Singapore', 'Yemen', 'Zambia', 'Zimbabwe']

group_map = {
    'United States': 'Developed Economies - Democracies', 'United Kingdom': 'Developed Economies - Democracies',
    'Germany': 'Developed Economies - Democracies', 'Japan': 'Developed Economies - Democracies', 'Australia': 'Developed Economies - Democracies',
    'Sweden': 'Developed Economies - Democracies', 'Canada': 'Developed Economies - Democracies', 'Finland': 'Developed Economies - Democracies',
    'Netherlands': 'Developed Economies - Democracies', 'Norway': 'Developed Economies - Democracies', 'Denmark': 'Developed Economies - Democracies',
    'Iceland': 'Developed Economies - Democracies', 'Ireland': 'Developed Economies - Democracies', 'Luxembourg': 'Developed Economies - Democracies',
    'Belgium': 'Developed Economies - Democracies', 'Austria': 'Developed Economies - Democracies', 'Switzerland': 'Developed Economies - Democracies',
    
    'Brazil': 'Emerging Economies - Democracies', 'Argentina': 'Emerging Economies - Democracies', 'India': 'Emerging Economies - Democracies',
    'Mexico': 'Emerging Economies - Democracies', 'South Africa': 'Emerging Economies - Democracies', 'Indonesia': 'Emerging Economies - Democracies',
    'Colombia': 'Emerging Economies - Democracies', 'Chile': 'Emerging Economies - Democracies', 'Costa Rica': 'Emerging Economies - Democracies',
    'Philippines': 'Emerging Economies - Democracies', 'Malaysia': 'Emerging Economies - Democracies', 'Thailand': 'Emerging Economies - Democracies',
    'Portugal': 'Emerging Economies - Democracies', 'Greece': 'Emerging Economies - Democracies', 'Hungary': 'Emerging Economies - Democracies',
    'Poland': 'Emerging Economies - Democracies', 'Romania': 'Emerging Economies - Democracies',
    
    'China': 'Emerging Economies - Authoritarianism', 'Russia': 'Emerging Economies - Authoritarianism', 'Saudi Arabia': 'Emerging Economies - Authoritarianism',
    'Iran': 'Emerging Economies - Authoritarianism', 'Vietnam': 'Emerging Economies - Authoritarianism', 'Turkey': 'Emerging Economies - Authoritarianism',
    'Egypt': 'Emerging Economies - Authoritarianism', 'Belarus': 'Emerging Economies - Authoritarianism', 'Kazakhstan': 'Emerging Economies - Authoritarianism',
    'Azerbaijan': 'Emerging Economies - Authoritarianism', 'Uzbekistan': 'Emerging Economies - Authoritarianism', 'Turkmenistan': 'Emerging Economies - Authoritarianism',
    
    'Afghanistan': 'Low-Income and Fragile States', 'Haiti': 'Low-Income and Fragile States', 'Sudan': 'Low-Income and Fragile States', 
    'Democratic Republic of Congo': 'Low-Income and Fragile States', 'Mozambique': 'Low-Income and Fragile States', 'Niger': 'Low-Income and Fragile States',
    'Guinea': 'Low-Income and Fragile States', 'Guinea-Bissau': 'Low-Income and Fragile States', 'Mali': 'Low-Income and Fragile States', 
    'Chad': 'Low-Income and Fragile States', 'Burundi': 'Low-Income and Fragile States', 'Lesotho': 'Low-Income and Fragile States', 
    'Liberia': 'Low-Income and Fragile States', 'Sierra Leone': 'Low-Income and Fragile States', 'Yemen': 'Low-Income and Fragile States', 
    'Somalia': 'Low-Income and Fragile States', 'Central African Republic': 'Low-Income and Fragile States',
    
    'Germany': 'European Union (EU) and Regional Powers', 'France': 'European Union (EU) and Regional Powers', 'Italy': 'European Union (EU) and Regional Powers',
    'Spain': 'European Union (EU) and Regional Powers', 'Poland': 'European Union (EU) and Regional Powers', 'Portugal': 'European Union (EU) and Regional Powers',
    'Greece': 'European Union (EU) and Regional Powers', 'Turkey': 'European Union (EU) and Regional Powers', 'Egypt': 'European Union (EU) and Regional Powers',
    'Israel': 'European Union (EU) and Regional Powers', 'Ukraine': 'European Union (EU) and Regional Powers', 'Bulgaria': 'European Union (EU) and Regional Powers',
    'Cyprus': 'European Union (EU) and Regional Powers', 'Slovenia': 'European Union (EU) and Regional Powers', 'Slovakia': 'European Union (EU) and Regional Powers',
    'Croatia': 'European Union (EU) and Regional Powers',
}


group_df = pd.DataFrame(list(group_map.items()), columns=['country', 'Group'])

group_df.to_csv('grouped_countries.csv', index=False)

print(group_df)
#group_df.to_csv("group_country.csv", index=False)
# Out:
#            country                                    Group
# 0    United States        Developed Economies - Democracies
# 1   United Kingdom        Developed Economies - Democracies
# 2          Germany  European Union (EU) and Regional Powers
# 3            Japan        Developed Economies - Democracies
# 4        Australia        Developed Economies - Democracies
# ..             ...                                      ...
# 68        Bulgaria  European Union (EU) and Regional Powers
# 69          Cyprus  European Union (EU) and Regional Powers
# 70        Slovenia  European Union (EU) and Regional Powers
# 71        Slovakia  European Union (EU) and Regional Powers
# 72         Croatia  European Union (EU) and Regional Powers
#
# [73 rows x 2 columns]

# %%
df_merge = pd.merge(df, group_df, how='inner', on='country')
df_merge
# Out:
#             country        date  total_cases  new_cases  new_cases_smoothed  \
# 0       Afghanistan  2020-01-01          NaN        NaN                 NaN
# 1       Afghanistan  2020-01-02          NaN        NaN                 NaN
# 2       Afghanistan  2020-01-03          NaN        NaN                 NaN
# 3       Afghanistan  2020-01-04          0.0        0.0                 NaN
# 4       Afghanistan  2020-01-05          0.0        0.0                 NaN
# ...             ...         ...          ...        ...                 ...
# 141375        Yemen  2025-03-26      11945.0        0.0                 0.0
# 141376        Yemen  2025-03-27      11945.0        0.0                 0.0
# 141377        Yemen  2025-03-28      11945.0        0.0                 0.0
# 141378        Yemen  2025-03-29      11945.0        0.0                 0.0
# 141379        Yemen  2025-03-30      11945.0        0.0                 0.0
#
# ...

# %%
duplicatas = df_merge[df_merge.duplicated()]

# Exibir as duplicatas, se houver
print(f"Number of duplicates: {duplicatas.shape[0]}")
# Out:
# Number of duplicates: 0

# %%
# Definir o limite de valores NaN permitido (por exemplo, 50% de NaNs)
limite_nan = 0.3

# Remover colunas com mais de 50% de NaN
df_merged = df_merge.loc[:, df_merge.isnull().mean() < limite_nan]

# Verificar as colunas restantes após a remoção
print(f"Colunas restantes após remoção de NaNs excessivos: {df_merged.columns}")
# Out:
# Colunas restantes após remoção de NaNs excessivos: Index(['country', 'date', 'total_cases', 'new_cases', 'new_cases_smoothed',
#        'total_cases_per_million', 'new_cases_per_million',
#        'new_cases_smoothed_per_million', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_deaths_per_million',
#        'new_deaths_per_million', 'new_deaths_smoothed_per_million', 'code',
#        'continent', 'population', 'population_density', 'median_age',
#        'gdp_per_capita', 'extreme_poverty', 'diabetes_prevalence',
#        'hospital_beds_per_thousand', 'human_development_index', 'Group'],
#       dtype='object')

# %%
# Verificar quantos NaNs há nas colunas restantes
print(f"Quantos NaNs restantes por coluna:")
print(df_merged.isnull().sum())
# Out:
# Quantos NaNs restantes por coluna:
# country                                0
# date                                   0
# total_cases                         1731
# new_cases                           4333
# new_cases_smoothed                  4696
# total_cases_per_million             1731
# new_cases_per_million               4333
# new_cases_smoothed_per_million      4696
# total_deaths                        1731
# new_deaths                          3641
# new_deaths_smoothed                 3991
# total_deaths_per_million            1731
# new_deaths_per_million              3641
# new_deaths_smoothed_per_million     3991
# code                                   0
# continent                              0
# population                             0
# population_density                     0
# median_age                             0
# gdp_per_capita                      1916
# extreme_poverty                    11516
# diabetes_prevalence                    0
# ...

# %%
df_merged = df_merged.dropna()

# Verificar o número de registros após a remoção das linhas com NaNs
print(f"Novo número de registros após remover todas as linhas com NaNs: {df_merged.shape[0]}")
df_merge
# Out:
# Novo número de registros após remover todas as linhas com NaNs: 106158
#             country        date  total_cases  new_cases  new_cases_smoothed  \
# 0       Afghanistan  2020-01-01          NaN        NaN                 NaN
# 1       Afghanistan  2020-01-02          NaN        NaN                 NaN
# 2       Afghanistan  2020-01-03          NaN        NaN                 NaN
# 3       Afghanistan  2020-01-04          0.0        0.0                 NaN
# 4       Afghanistan  2020-01-05          0.0        0.0                 NaN
# ...             ...         ...          ...        ...                 ...
# 141375        Yemen  2025-03-26      11945.0        0.0                 0.0
# 141376        Yemen  2025-03-27      11945.0        0.0                 0.0
# 141377        Yemen  2025-03-28      11945.0        0.0                 0.0
# 141378        Yemen  2025-03-29      11945.0        0.0                 0.0
# ...

# %%
# Verificar duplicação por país e data
df_duplicates = df_merged[df_merged.duplicated(subset=['country', 'date'], keep=False)]

# Remover duplicações, se necessário
df_merged = df_merged.drop_duplicates(subset=['country', 'date'])

# %%
# Agrupar pelo país e contar o número de datas únicas para cada país
dates_per_country = df_merged.groupby('country')['date'].nunique()

# Calcular a média de datas por país
mean_dates_per_country = dates_per_country.mean()

print(f"Média de datas por país: {mean_dates_per_country:.2f}")
# Out:
# Média de datas por país: 1862.42

# %%
# Garantir que a coluna 'date' está no formato datetime
df_merged['date'] = pd.to_datetime(df_merged['date'], errors='coerce')
# Extrair o ano de cada data
df_merged['year'] = df_merged['date'].dt.year

# Encontrar o ano mínimo e o máximo
min_year = df_merged['year'].min()
max_year = df_merged['year'].max()

print(f"O dataset vai de {min_year} a {max_year}")
# Out:
# O dataset vai de 2020 a 2025

# %%
# Garantir que a coluna 'date' está no formato datetime
df_merged['date'] = pd.to_datetime(df_merged['date'], errors='coerce')

# Extrair o ano e o mês da coluna 'date'
df_merged['year'] = df_merged['date'].dt.year
df_merged['month'] = df_merged['date'].dt.month

# Agrupar os dados por país, ano e mês, somando as mortes e outros dados de interesse
df_monthly = df_merged.groupby(['country', 'year', 'month']).agg({
    'total_deaths': 'sum',
    'new_deaths': 'sum',
    'total_cases': 'sum',
    'new_cases': 'sum',
    'gdp_per_capita': 'mean',  # Para PIB per capita, pega a média
    'human_development_index': 'mean',  # Para HDI, pega a média
    'extreme_poverty': 'mean',  # Média de pobreza extrema
    'diabetes_prevalence': 'mean',  # Média de prevalência de diabetes
    'hospital_beds_per_thousand': 'mean',  # Média de leitos hospitalares
    'population': 'last'  # Pega o valor da população no último dia do mês
}).reset_index()

# Verificar os primeiros registros para confirmar que a transformação foi bem-sucedida
print(df_monthly.head())
# Out:
#      country  year  month  total_deaths  new_deaths  total_cases  new_cases  \
# 0  Australia  2020      1           0.0         0.0         35.0        9.0
# 1  Australia  2020      2           0.0         0.0        478.0       16.0
# 2  Australia  2020      3         231.0        21.0      31988.0     4334.0
# 3  Australia  2020      4        1895.0        74.0     186937.0     2387.0
# 4  Australia  2020      5        3204.0        12.0     216814.0      439.0
#
#    gdp_per_capita  human_development_index  extreme_poverty  \
# 0        51090.26                    0.946         0.497094
# 1        51090.26                    0.946         0.497094
# 2        51090.26                    0.946         0.497094
# 3        51090.26                    0.946         0.497094
# 4        51090.26                    0.946         0.497094
#
#    diabetes_prevalence  hospital_beds_per_thousand  population
# 0                  6.4                        3.84  26200929.0
# ...

# %%
# Fazendo o merge entre df_monthly e df_group_df para adicionar a coluna 'Group'
df_merged_group = pd.merge(df_monthly, group_df, how='left', on='country')

# Agrupar os dados por grupo e somar as colunas de interesse
df_grouped = df_merged_group.groupby(['Group', 'year', 'month']).agg({
    'total_deaths': 'sum',
    'new_deaths': 'sum',
    'total_cases': 'sum',
    'new_cases': 'sum',
    'population': 'sum',  # Soma da população (pode ser ajustada para média, caso necessário)
    'gdp_per_capita': 'mean',  # Média de PIB per capita
    'human_development_index': 'mean',  # Média de HDI
    'extreme_poverty': 'mean',  # Média de pobreza extrema
    'diabetes_prevalence': 'mean',  # Média de prevalência de diabetes
    'hospital_beds_per_thousand': 'mean',  # Média de leitos hospitalares
}).reset_index()

# Verificar os primeiros registros para confirmar que a transformação foi bem-sucedida
print(df_grouped.head())
# Out:
#                                Group  year  month  total_deaths  new_deaths  \
# 0  Developed Economies - Democracies  2020      1           0.0         0.0
# 1  Developed Economies - Democracies  2020      2          90.0         9.0
# 2  Developed Economies - Democracies  2020      3       54018.0     10354.0
# 3  Developed Economies - Democracies  2020      4     1976024.0    110616.0
# 4  Developed Economies - Democracies  2020      5     5031499.0     69550.0
#
#    total_cases  new_cases   population  gdp_per_capita  \
# 0        157.0       33.0  680695519.0    63296.386313
# 1       4997.0      447.0  680695519.0    63296.386312
# 2    1902799.0   284590.0  680695519.0    63296.386312
# 3   26979289.0  1180354.0  680695519.0    63296.386312
# 4   61342338.0   932074.0  680695519.0    63296.386312
#
#    human_development_index  extreme_poverty  diabetes_prevalence  \
# 0                 0.943562         0.291565               5.5875
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by Group, Year, and Month, summing up the total cases
df_grouped_cases = df_grouped.groupby(['Group', 'year', 'month'])['total_cases'].sum().reset_index()

# Create a 'date' column for proper time representation
df_grouped_cases['date'] = pd.to_datetime(df_grouped_cases[['year', 'month']].assign(day=1))

# Plot the line chart
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_grouped_cases, x='date', y='total_cases', hue='Group', marker='o')

# Titles and labels
plt.title('Total COVID Cases Trend by Group Over Time', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Total Cases', fontsize=12)
plt.legend(title='Country Group')
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Group the data by Group, Year, and Month, summing up the total cases and population
df_grouped_cases = df_grouped.groupby(['Group', 'year', 'month']).agg({
    'total_cases': 'sum',
    'population': 'sum'  # Sum up the population for each group
}).reset_index()

# Calculate the percentage of cases in relation to the population
df_grouped_cases['cases_percentage'] = (df_grouped_cases['total_cases'] / df_grouped_cases['population']) 

# Create a 'date' column for proper time representation
df_grouped_cases['date'] = pd.to_datetime(df_grouped_cases[['year', 'month']].assign(day=1))

# Plot the line chart
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_grouped_cases, x='date', y='cases_percentage', hue='Group', marker='o')

# Titles and labels
plt.title('Percentage of COVID Cases Relative to Population by Group Over Time', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Percentage of Population Infected (%)', fontsize=12)
plt.legend(title='Country Group')
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()
plt.show()

# %%
# Group the data by Group, Year, and Month, summing up deaths and cases
df_grouped_mortality = df_grouped.groupby(['Group', 'year', 'month']).agg({
    'total_deaths': 'sum',
    'total_cases': 'sum'
}).reset_index()

# Calculate the mortality rate (avoid division by zero)
df_grouped_mortality['mortality_rate'] = (df_grouped_mortality['total_deaths'] / df_grouped_mortality['total_cases']) * 100
df_grouped_mortality['mortality_rate'].fillna(0, inplace=True)  # Replace NaN values with 0

# Create a 'date' column for proper time representation
df_grouped_mortality['date'] = pd.to_datetime(df_grouped_mortality[['year', 'month']].assign(day=1))

# Identify the first row for the European group in 2020
mask = (df_grouped_mortality['Group'] == 'European Union (EU) and Regional Powers') & (df_grouped_mortality['year'] == 2020)

# Drop the first occurrence of this row
df_grouped_mortality = df_grouped_mortality[~(mask & (df_grouped_mortality.index == mask.idxmax()))]

# Plot the line chart
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_grouped_mortality, x='date', y='mortality_rate', hue='Group', marker='o')

# Titles and labels
plt.title('COVID-19 Mortality Rate by Group Over Time', fontsize=14)
plt.xlabel('Date', fontsize=12)
plt.ylabel('Mortality Rate (%)', fontsize=12)
plt.legend(title='Country Group')
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()
plt.show()
# Out:
# /var/folders/mg/trj2dw9n74q5lcbvnrpm0lkw0000gn/T/ipykernel_85785/2708437157.py:9: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by Group, Year, and Month, summing up the total cases
df_grouped_cases = df_grouped.groupby(['Group', 'year', 'month'])['gdp_per_capita'].sum().reset_index()

# Create a 'date' column for proper time representation
df_grouped_cases['date'] = pd.to_datetime(df_grouped_cases[['year', 'month']].assign(day=1))

# Plot the line chart
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_grouped_cases, x='date', y='gdp_per_capita', hue='Group', marker='o')

# Titles and labels
plt.title('GDP per Capita Over Time', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.legend(title='Indicators')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Group the data by Group, Year, and Month, summing up the total cases
df_grouped_cases = df_grouped.groupby(['Group', 'year', 'month'])['human_development_index'].sum().reset_index()

# Create a 'date' column for proper time representation
df_grouped_cases['date'] = pd.to_datetime(df_grouped_cases[['year', 'month']].assign(day=1))

# Plot the line chart
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_grouped_cases, x='date', y='human_development_index', hue='Group', marker='o')

# Titles and labels
plt.title('HDI Over Time', fontsize=14)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Value', fontsize=12)
plt.legend(title='Indicators')

# Display the plot
plt.tight_layout()
plt.show()

# %%
print(df_grouped.head())
# Out:
#                                Group  year  month  total_deaths  new_deaths  \
# 0  Developed Economies - Democracies  2020      1           0.0         0.0
# 1  Developed Economies - Democracies  2020      2          90.0         9.0
# 2  Developed Economies - Democracies  2020      3       54018.0     10354.0
# 3  Developed Economies - Democracies  2020      4     1976024.0    110616.0
# 4  Developed Economies - Democracies  2020      5     5031499.0     69550.0
#
#    total_cases  new_cases   population  gdp_per_capita  \
# 0        157.0       33.0  680695519.0    63296.386313
# 1       4997.0      447.0  680695519.0    63296.386312
# 2    1902799.0   284590.0  680695519.0    63296.386312
# 3   26979289.0  1180354.0  680695519.0    63296.386312
# 4   61342338.0   932074.0  680695519.0    63296.386312
#
#    human_development_index  extreme_poverty  diabetes_prevalence  \
# 0                 0.943562         0.291565               5.5875
# ...

# %% [markdown]
# dataset = https://www.kaggle.com/datasets/joseventura21/turismsdataset

# %%
df_turism = pd.read_csv("turism.csv")
print(df_turism)
# Out:
#              DATE COUNTRY \nCODE TRANSP. \nMETHOD  QUANTITY      Country Code  \
# 0      2017-01-01             AN              Sea     30604      Andorra   AN
# 1      2017-01-01             IN              Air     38710        India   IN
# 2      2017-01-01             GE              Air     35007      Germany   GE
# 3      2017-01-01             JP              Sea     33518        Japan   JP
# 4      2017-01-01             SU              Air     30227     Suriname   SU
# ...           ...            ...              ...       ...          ...  ...
# 58335  2015-12-27             GE              Air     32681      Germany   GE
# 58336  2015-12-28             SW              Sea     36140  Switzerland   SW
# 58337  2015-12-29             GU              Sea     37956    Guatemala   GU
# 58338  2015-12-30             SK              Air     37591  South Korea   SK
# 58339  2015-12-31             AL              Air     38178      Albania   AL
#
#       CONTINENT
# ...

# %%
# Realizar o merge entre os dois DataFrames usando a coluna 'Country'
merged_turism = pd.merge(df_turism, group_df, how='inner', left_on='Country', right_on='country')

# Visualizar as primeiras linhas do DataFrame resultante
print(merged_turism.head())
# Out:
#          DATE COUNTRY \nCODE TRANSP. \nMETHOD  QUANTITY   Country Code  \
# 0  2017-01-01             IN              Air     38710     India   IN
# 1  2017-01-01             GE              Air     35007   Germany   GE
# 2  2017-01-01             JP              Sea     33518     Japan   JP
# 3  2017-01-01             CH              Air     31343     China   CH
# 4  2017-01-01             CO              Air     30529  Colombia   CO
#
#   CONTINENT   country                                    Group
# 0        AS     India         Emerging Economies - Democracies
# 1        EU   Germany  European Union (EU) and Regional Powers
# 2        AS     Japan        Developed Economies - Democracies
# 3        AS     China    Emerging Economies - Authoritarianism
# 4        AM  Colombia         Emerging Economies - Democracies

# %%
merged_turism = merged_turism.dropna()
merged_turism = merged_turism.drop_duplicates()

# %%
# Converter a coluna 'DATE' para datetime
merged_turism['DATE'] = pd.to_datetime(merged_turism['DATE'])

# Extrair ano e mês
merged_turism['Year'] = merged_turism['DATE'].dt.year
merged_turism['Month'] =merged_turism['DATE'].dt.month

# Agrupar por ano e mês e somar a quantidade
monthly_data = merged_turism.groupby(['Group','Year', 'Month'])['QUANTITY'].sum().reset_index()

# Visualizar o resultado
print(monthly_data)
# Out:
#                                  Group  Year  Month  QUANTITY
# 0    Developed Economies - Democracies  2015      1   4424312
# 1    Developed Economies - Democracies  2015      2   3738377
# 2    Developed Economies - Democracies  2015      3   3616143
# 3    Developed Economies - Democracies  2015      4   3924185
# 4    Developed Economies - Democracies  2015      5   3993257
# ..                                 ...   ...    ...       ...
# 415      Low-Income and Fragile States  2021      8    109651
# 416      Low-Income and Fragile States  2021      9     65935
# 417      Low-Income and Fragile States  2021     10    321158
# 418      Low-Income and Fragile States  2021     11    148899
# 419      Low-Income and Fragile States  2021     12    113065
#
# [420 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

# Group by Group and Year, then sum the quantities
grouped_evolution = monthly_data.groupby(['Group', 'Year'])['QUANTITY'].sum().reset_index()

# Plot the evolution of groups over the years
plt.figure(figsize=(10, 6))

for group in grouped_evolution['Group'].unique():
    group_data = grouped_evolution[grouped_evolution['Group'] == group]
    plt.plot(group_data['Year'], group_data['QUANTITY'], label=group)

plt.xlabel('Year')
plt.ylabel('Quantity of Tourists')
plt.title('Evolution of Groups Over the Years')
plt.legend(title='Groups')
plt.grid(True)
plt.show()

# %%
import plotly.express as px

# Filter data for Europe and group by continent and country
europe_data = merged_turism[merged_turism['CONTINENT'] == 'EU']

# Loop through each year and create a treemap
for year in europe_data['Year'].unique():
    year_data = europe_data[europe_data['Year'] == year]
    fig = px.treemap(year_data, 
                     path=['CONTINENT', 'country'], 
                     values='QUANTITY', 
                     title=f"Tourism in Europe by Country in {year}")
    fig.show()

# %%
# Filter data for the last 6 months of 2019 and up to 2021
covid_period = merged_turism[(merged_turism['DATE'] >= '2019-06-01') & (merged_turism['DATE'] <= '2021-12-31')]

# Extract year and month
covid_period['Year'] = covid_period['DATE'].dt.year
covid_period['Month'] = covid_period['DATE'].dt.month

# Group by year, month, and continent, and sum the quantity
covid_grouped = covid_period.groupby(['CONTINENT', 'Year', 'Month'])['QUANTITY'].sum().reset_index()
# Out:
# /var/folders/mg/trj2dw9n74q5lcbvnrpm0lkw0000gn/T/ipykernel_85785/3608318639.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/mg/trj2dw9n74q5lcbvnrpm0lkw0000gn/T/ipykernel_85785/3608318639.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot the data for each continent
for continent in covid_grouped['CONTINENT'].unique():
    continent_data = covid_grouped[covid_grouped['CONTINENT'] == continent]
    plt.plot(continent_data['Year'].astype(str) + '-' + continent_data['Month'].astype(str), continent_data['QUANTITY'], label=continent)

plt.xlabel('Year-Month')
plt.ylabel('Quantity of Tourists')
plt.title('Tourism Trends by Continent Before and After COVID-19')
plt.xticks(rotation=45)
plt.legend(title='Continent')
plt.grid(True)
plt.show()

# %%
turism = pd.read_csv("turism.csv")
europe_df = turism[turism['CONTINENT'] == 'EU']
europe_df["DATE"] = pd.to_datetime(europe_df["DATE"])
europe_df["Year"] = europe_df["DATE"].dt.year
europe_yearly = europe_df.groupby(['Year', 'Code', 'Country'])['QUANTITY'].sum().reset_index()
europe_yearly
# Out:
# /var/folders/mg/trj2dw9n74q5lcbvnrpm0lkw0000gn/T/ipykernel_85785/121606695.py:3: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/mg/trj2dw9n74q5lcbvnrpm0lkw0000gn/T/ipykernel_85785/121606695.py:4: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      Year Code                 Country  QUANTITY
# 0    2015   AL                 Albania   2825671
# 1    2015   AN                 Andorra   3169167
# 2    2015   AU                 Austria   3160676
# ...

# %%
import pycountry

# Função para mapear nome do país para código ISO-3
def get_iso3(country_name):
    try:
        return pycountry.countries.lookup(country_name).alpha_3
    except:
        return None  # se não encontrar, deixa vazio pra gente filtrar depois

# Aplicar no DataFrame
europe_yearly['ISO3'] = europe_yearly['Country'].apply(get_iso3)
europe_yearly = europe_yearly.dropna(subset=['ISO3'])

# %%
import numpy as np 

years = np.unique(europe_yearly["Year"])
years
# Out:
# array([2015, 2016, 2017, 2018, 2019, 2020, 2021], dtype=int32)

# %%
fig = px.choropleth(
    europe_yearly,
    locations='ISO3',
    color='QUANTITY',
    hover_name='Country',
    animation_frame='Year',   # isso adiciona o slider!
    color_continuous_scale='Viridis',
    projection='natural earth',
    title='Turismo na Europa por Ano'
)

fig.update_geos(scope='europe')
fig.show()

# %%
# Filtrar só a América
america_df = turism[turism['CONTINENT'] == 'AM'].copy()

# Certificar que a coluna 'Year' está lá
america_df['DATE'] = pd.to_datetime(america_df['DATE'])
america_df['Year'] = america_df['DATE'].dt.year

# Agrupar por ano, país e código
america_yearly = america_df.groupby(['Year', 'Country', 'Code'])['QUANTITY'].sum().reset_index()

# %%
america_yearly['ISO3'] = america_yearly['Country'].apply(get_iso3)

# Remover países que não foram encontrados
america_yearly = america_yearly.dropna(subset=['ISO3'])

# %%
fig = px.choropleth(
    america_yearly,
    locations='ISO3',
    color='QUANTITY',
    hover_name='Country',
    animation_frame='Year',
    color_continuous_scale='YlOrRd',
    projection='natural earth',
    title='Turismo nas Américas por Ano'
)

# Focar nas Américas
fig.update_geos(scope='north america')  # isso mostra toda América
fig.show()

# %%
fig.update_geos(scope='south america')  # isso mostra toda América
fig.show()

# %%
# Filtrar só a América
africa_df = turism[turism['CONTINENT'] == 'AF'].copy()

# Certificar que a coluna 'Year' está lá
africa_df['DATE'] = pd.to_datetime(africa_df['DATE'])
africa_df['Year'] = africa_df['DATE'].dt.year

# Agrupar por ano, país e código
africa_yearly = africa_df.groupby(['Year', 'Country', 'Code'])['QUANTITY'].sum().reset_index()
africa_yearly['ISO3'] = africa_yearly['Country'].apply(get_iso3)

# Remover países que não foram encontrados
africa_yearly = africa_yearly.dropna(subset=['ISO3'])

# %%
fig = px.choropleth(
    africa_yearly,
    locations='ISO3',
    color='QUANTITY',
    hover_name='Country',
    animation_frame='Year',
    color_continuous_scale='YlOrRd',
    projection='natural earth',
    title='Turismo nas Africa por Ano'
)

# Focar nas Américas
fig.update_geos(scope='africa')  # isso mostra toda América
fig.show()

# %%
# Filtrar só a América
asia_df = turism[turism['CONTINENT'] == 'AS'].copy()

# Certificar que a coluna 'Year' está lá
asia_df['DATE'] = pd.to_datetime(asia_df['DATE'])
asia_df['Year'] = asia_df['DATE'].dt.year

# Agrupar por ano, país e código
asia_yearly = asia_df.groupby(['Year', 'Country', 'Code'])['QUANTITY'].sum().reset_index()
asia_yearly['ISO3'] = asia_yearly['Country'].apply(get_iso3)

# Remover países que não foram encontrados
asia_yearly = asia_yearly.dropna(subset=['ISO3'])

# %%
fig = px.choropleth(
    asia_yearly,
    locations='ISO3',
    color='QUANTITY',
    hover_name='Country',
    animation_frame='Year',
    color_continuous_scale='YlOrRd',
    projection='natural earth',
    title='Turismo nas Asia por Ano'
)

# Focar nas Américas
fig.update_geos(scope='asia')  # isso mostra toda América
fig.show()

# %%
turism.head()
# Out:
#          DATE COUNTRY \nCODE TRANSP. \nMETHOD  QUANTITY   Country Code  \
# 0  2017-01-01             AN              Sea     30604   Andorra   AN
# 1  2017-01-01             IN              Air     38710     India   IN
# 2  2017-01-01             GE              Air     35007   Germany   GE
# 3  2017-01-01             JP              Sea     33518     Japan   JP
# 4  2017-01-01             SU              Air     30227  Suriname   SU
#
#   CONTINENT
# 0        EU
# 1        AS
# 2        EU
# 3        AS
# 4        AM

# %%
turism['DATE'] = pd.to_datetime(turism['DATE'])
turism['Year'] = turism['DATE'].dt.year
sea_df = turism[turism['TRANSP. \nMETHOD'] == 'Sea']
air_df = turism[turism['TRANSP. \nMETHOD'] == 'Air']

sea_yearly = sea_df.groupby(['Year', 'Country', 'Code'])['QUANTITY'].sum().reset_index()
sea_yearly['ISO3'] = sea_yearly['Country'].apply(get_iso3)


air_yearly = air_df.groupby(['Year', 'Country', 'Code'])['QUANTITY'].sum().reset_index()
air_yearly['ISO3'] = air_yearly['Country'].apply(get_iso3)
air_yearly = air_yearly.dropna(subset=['ISO3'])

# %%
sea_yearly
# Out:
#      Year         Country Code  QUANTITY ISO3
# 0    2015         Albania   AL   1508787  ALB
# 1    2015         Andorra   AN   1607884  AND
# 2    2015       Argentina   AR   1310499  ARG
# 3    2015       Australia   AT   1405193  AUS
# 4    2015         Austria   AU   2004631  AUT
# ..    ...             ...  ...       ...  ...
# 590  2021         Ukraine  UKR   1334379  UKR
# 591  2021  United Kingdom   UK   1388688  GBR
# 592  2021   United States   US   1280329  USA
# 593  2021         Uruguay   UR   1711432  URY
# 594  2021       Venezuela   VE   1431052  VEN
#
# [595 rows x 5 columns]

# %%
# Criar o mapa para o transporte Sea
fig_sea = px.choropleth(
    sea_yearly,
    locations='ISO3',        # Códigos dos países
    color='QUANTITY',        # Quantidade de turistas
    hover_name='Country',    # Nome do país
    animation_frame='Year',  # Animar por ano
    color_continuous_scale='Viridis',
    projection='natural earth',
    title='Turismo Marítimo (Sea) por Ano'
)

fig_sea.update_geos(scope='world')  # Mapa do mundo
fig_sea.show()

# %%
# Criar o mapa para o transporte Sea
fig_sea = px.choropleth(
    air_yearly,
    locations='ISO3',        # Códigos dos países
    color='QUANTITY',        # Quantidade de turistas
    hover_name='Country',    # Nome do país
    animation_frame='Year',  # Animar por ano
    color_continuous_scale='Viridis',
    projection='natural earth',
    title='Turismo Air por Ano'
)

fig_sea.update_geos(scope='world')  # Mapa do mundo
fig_sea.show()

# %%
turism['ISO3'] = turism['Country'].apply(get_iso3)
# Filtrar para os meses de 2020 (por exemplo, março a dezembro)
covid_months_df = turism[(turism['DATE'].dt.year == 2020) & (turism['DATE'].dt.month >= 3)]

# Verificar os primeiros dados para garantir que o filtro está correto
print(covid_months_df.head())
# Out:
#             DATE COUNTRY \nCODE TRANSP. \nMETHOD  QUANTITY            Country  \
# 23040 2020-03-01             CA              Air     37870             Canada
# 23041 2020-03-01             SU              Sea     37809           Suriname
# 23042 2020-03-01             EQ              Air     31660  Equatorial Guinea
# 23043 2020-03-01             PG              Sea     33617           Paraguay
# 23044 2020-03-01             PR              Air     37899        Puerto Rico
#
#       Code CONTINENT  Year ISO3
# 23040   CA        AM  2020  CAN
# 23041   SU        AM  2020  SUR
# 23042   EQ        AF  2020  GNQ
# 23043   PG        AM  2020  PRY
# 23044   PR        AM  2020  PRI

# %%
# Agrupar os dados por Year, Month, Country, e TRANSP. METHOD
sea_covid_monthly = covid_months_df[covid_months_df['TRANSP. \nMETHOD'] == 'Sea']
air_covid_monthly = covid_months_df[covid_months_df['TRANSP. \nMETHOD'] == 'Air']
# Adicionar coluna de Month (caso não tenha sido feita antes)
sea_covid_monthly['Month'] = sea_covid_monthly['DATE'].dt.month
air_covid_monthly['Month'] = air_covid_monthly['DATE'].dt.month

# Agrupar os dados por ano, mês, país, e código
sea_covid_monthly_grouped = sea_covid_monthly.groupby(['Year', 'Month', 'Country', 'ISO3'])['QUANTITY'].sum().reset_index()
air_covid_monthly_grouped = air_covid_monthly.groupby(['Year', 'Month', 'Country', 'ISO3'])['QUANTITY'].sum().reset_index()
# Out:
# /var/folders/mg/trj2dw9n74q5lcbvnrpm0lkw0000gn/T/ipykernel_85785/3659604114.py:5: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /var/folders/mg/trj2dw9n74q5lcbvnrpm0lkw0000gn/T/ipykernel_85785/3659604114.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))

# Plot the data for each continent
for continent in covid_grouped['CONTINENT'].unique():
    continent_data = covid_grouped[covid_grouped['CONTINENT'] == continent]
    plt.plot(continent_data['Year'].astype(str) + '-' + continent_data['Month'].astype(str), continent_data['QUANTITY'], label=continent)

plt.xlabel('Year-Month')
plt.ylabel('Quantity of Tourists')
plt.title('Tourism by Continent Before and After COVID-19')
plt.xticks(rotation=45)
plt.legend(title='Continent')
plt.grid(True)
plt.show()

# %%
import plotly.express as px

# Criar o gráfico para o transporte Sea durante a pandemia
fig_sea_covid = px.choropleth(
    sea_covid_monthly_grouped,
    locations='ISO3',
    color='QUANTITY',
    hover_name='Country',
    animation_frame='Month',  # Animar por mês dentro de 2020
    color_continuous_scale='Viridis',
    projection='natural earth',
    title='Turism on sea during COVID-19'
)

fig_sea_covid.update_geos(scope='world')  # Exibir o mapa do mundo
fig_sea_covid.show()

# Criar o gráfico para o transporte Air durante a pandemia
fig_air_covid = px.choropleth(
    air_covid_monthly_grouped,
    locations='ISO3',
    color='QUANTITY',
    hover_name='Country',
    animation_frame='Month',  # Animar por mês dentro de 2020
    color_continuous_scale='Viridis',
    projection='natural earth',
    title='Turism on Air during COVID-19'
)

fig_air_covid.update_geos(scope='world')  # Exibir o mapa do mundo
fig_air_covid.show()

# %%
import dash
from dash import dcc, html
import plotly.express as px
import matplotlib.pyplot as plt
from io import BytesIO
import base64

# Initialize Dash app
app = dash.Dash(__name__)

# Convert matplotlib figure to PNG image
def matplotlib_to_plotly():
    plt.figure(figsize=(12, 6))
    
    # Plot data for each continent (using your actual data)
    for continent in covid_grouped['CONTINENT'].unique():
        continent_data = covid_grouped[covid_grouped['CONTINENT'] == continent]
        plt.plot(continent_data['Year'].astype(str) + '-' + continent_data['Month'].astype(str), 
                 continent_data['QUANTITY'], label=continent)

    plt.xlabel('Year-Month')
    plt.ylabel('Number of Tourists')
    plt.title('Tourism Trends by Continent Before and After COVID-19')
    plt.xticks(rotation=45)
    plt.legend(title='Continent')
    plt.grid(True)
    
    # Save figure to bytes
    buf = BytesIO()
    plt.savefig(buf, format='png', bbox_inches='tight')
    plt.close()
    return base64.b64encode(buf.getvalue()).decode('utf8')

# Dashboard layout
app.layout = html.Div([
    html.H1("Tourism Analysis During COVID-19", style={'textAlign': 'center'}),
    
    html.Div([
        html.H2("Tourism Trends by Continent"),
        html.Img(src='data:image/png;base64,{}'.format(matplotlib_to_plotly()))
    ], style={'padding': '20px', 'border': '1px solid #ddd', 'margin': '10px'}),
    
    html.Div([
        html.H2("Sea Transportation Tourism"),
        dcc.Graph(
            id='sea-transport',
            figure=px.choropleth(
                sea_covid_monthly_grouped,
                locations='ISO3',
                color='QUANTITY',
                hover_name='Country',
                animation_frame='Month',
                color_continuous_scale='Viridis',
                projection='natural earth',
                title='Sea Transportation Tourism During COVID-19'
            ).update_geos(scope='world')
        )
    ], style={'padding': '20px', 'border': '1px solid #ddd', 'margin': '10px'}),
    
    html.Div([
        html.H2("Air Transportation Tourism"),
        dcc.Graph(
            id='air-transport',
            figure=px.choropleth(
                air_covid_monthly_grouped,
                locations='ISO3',
                color='QUANTITY',
                hover_name='Country',
                animation_frame='Month',
                color_continuous_scale='Viridis',
                projection='natural earth',
                title='Air Transportation Tourism During COVID-19'
            ).update_geos(scope='world')
        )
    ], style={'padding': '20px', 'border': '1px solid #ddd', 'margin': '10px'})
])

# Run the server (updated syntax)
if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
from dash import dcc, html
import plotly.express as px
import matplotlib.pyplot as plt
from io import BytesIO
import base64
from jupyter_dash import JupyterDash
import webbrowser

# Initialize app - using standard Dash for compatibility
app = JupyterDash(__name__)

# Convert matplotlib figure to PNG image
def matplotlib_to_plotly():
    plt.figure(figsize=(12, 6))
    
    for continent in covid_grouped['CONTINENT'].unique():
        continent_data = covid_grouped[covid_grouped['CONTINENT'] == continent]
        plt.plot(continent_data['Year'].astype(str) + '-' + continent_data['Month'].astype(str), 
                 continent_data['QUANTITY'], label=continent)

    plt.xlabel('Year-Month')
    plt.ylabel('Number of Tourists')
    plt.title('Tourism Trends by Continent Before and After COVID-19')
    plt.xticks(rotation=45)
    plt.legend(title='Continent')
    plt.grid(True)
    
    buf = BytesIO()
    plt.savefig(buf, format='png', bbox_inches='tight')
    plt.close()
    return base64.b64encode(buf.getvalue()).decode('utf8')

# Dashboard layout
app.layout = html.Div([
    html.H1("Tourism Analysis During COVID-19", style={'textAlign': 'center'}),
    
    html.Div([
        html.H2("Tourism Trends by Continent"),
        html.Img(src='data:image/png;base64,{}'.format(matplotlib_to_plotly()))
    ], style={'padding': '20px', 'border': '1px solid #ddd', 'margin': '10px'}),
    
    html.Div([
        html.H2("Sea Transportation Tourism"),
        dcc.Graph(
            id='sea-transport',
            figure=px.choropleth(
                sea_covid_monthly_grouped,
                locations='ISO3',
                color='QUANTITY',
                hover_name='Country',
                animation_frame='Month',
                color_continuous_scale='Viridis',
                projection='natural earth',
                title='Sea Transportation Tourism During COVID-19'
            ).update_geos(scope='world')
        )
    ], style={'padding': '20px', 'border': '1px solid #ddd', 'margin': '10px'}),
    
    html.Div([
        html.H2("Air Transportation Tourism"),
        dcc.Graph(
            id='air-transport',
            figure=px.choropleth(
                air_covid_monthly_grouped,
                locations='ISO3',
                color='QUANTITY',
                hover_name='Country',
                animation_frame='Month',
                color_continuous_scale='Viridis',
                projection='natural earth',
                title='Air Transportation Tourism During COVID-19'
            ).update_geos(scope='world')
        )
    ], style={'padding': '20px', 'border': '1px solid #ddd', 'margin': '10px'})
])

# Run the server with automatic browser opening
port = 8050
app.run_server(mode='external', port=port)
webbrowser.open_new(f"http://localhost:{port}")
# Out:
# /opt/anaconda3/envs/mook/lib/python3.11/site-packages/dash/dash.py:586: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 80
#      78 # Run the server with automatic browser opening
#      79 port = 8050
# ---> 80 app.run_server(mode='external', port=port)
#      81 webbrowser.open_new(f"http://localhost:{port}")
#
# File /opt/anaconda3/envs/mook/lib/python3.11/site-packages/jupyter_dash/jupyter_app.py:176, in JupyterDash.run_server(self, mode, width, height, inline_exceptions, **kwargs)
#     154 """
#     155 Serve the app using flask in a background thread. You should not run this on a
#     156 production server, use gunicorn/waitress instead.
#    (...)    173     ``Dash.run_server`` method.
#     174 """
# ...
